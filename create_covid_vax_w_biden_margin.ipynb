# %%
import numpy as np
import pandas as pd

# %%
covid_df = pd.read_excel('covid_by_state_flourish.xlsx')
biden_df = pd.read_excel('biden_prop.xlsx')

# %%
covid_vax_w_biden_margin = covid_df.merge(biden_df, left_on='state', right_on='state_abbr')

# %%
covid_vax_w_biden_margin
# Out:
#    state_x  12/09/2021  12/08/2021  12/07/2021  12/06/2021  12/05/2021  \
# 0       AK        63.8        63.7        63.6        63.6        63.4
# 1       AL        57.3        57.3        57.2        57.1        57.1
# 2       AR        61.4        61.3        61.1        61.1        61.0
# 3       AZ        65.4        65.2        65.1        65.1        65.0
# 4       CA        80.1        80.0        79.8        79.8        79.6
# 5       CO        72.5        72.4        72.3        72.2        72.1
# 6       CT        85.5        85.3        85.1        85.0        85.0
# 7       DC        83.7        83.5        83.2        83.0        82.7
# 8       DE        74.4        74.2        73.5        73.5        73.5
# 9       FL        72.5        72.5        72.5        72.5        72.4
# 10      GA        59.8        59.7        59.6        59.4        59.4
# 11      HI        83.1        83.0        82.9        82.8        82.8
# ...

# %%
covid_vax_w_biden_margin.to_excel('covid_vax_w_biden_margin.xlsx')
